# %%
faqs = """Artificial Intelligence (AI) is one of the most transformative technologies of the modern era. It has evolved from being a mere concept in science fiction to becoming an integral part of everyday life. AI refers to the simulation of human intelligence in machines, enabling them to perform tasks that typically require human cognition, such as learning, reasoning, problem-solving, and decision-making. The journey of AI can be traced back to the mid-20th century when pioneers like Alan Turing and John McCarthy laid the theoretical foundations for the field. Turing’s work on the Turing Test and McCarthy’s introduction of the term “artificial intelligence” in 1956 were pivotal moments in AI history. Early AI research focused on symbolic reasoning and rule-based systems, which led to the development of expert systems in the 1970s and 1980s. These systems, however, had limitations in handling real-world complexities. The advent of machine learning in the late 20th century marked a paradigm shift, as computers could now learn from data rather than relying solely on predefined rules.

Machine learning, a subset of AI, leverages statistical techniques to enable machines to improve their performance on tasks with experience. This development paved the way for deep learning, a more advanced form of machine learning inspired by the structure and function of the human brain’s neural networks. Deep learning has driven many of the recent breakthroughs in AI, such as natural language processing, computer vision, and autonomous systems. One of the most widely recognized applications of AI is in voice assistants like Siri, Alexa, and Google Assistant. These systems utilize natural language processing to understand and respond to user queries. Similarly, AI-powered chatbots are revolutionizing customer service by providing instant and efficient responses to customer inquiries.

In healthcare, AI is playing a critical role in diagnosing diseases, predicting patient outcomes, and personalizing treatment plans. Machine learning algorithms can analyze medical images, such as X-rays and MRIs, to detect anomalies with remarkable accuracy. AI-driven predictive analytics are also helping doctors anticipate disease outbreaks and optimize resource allocation in hospitals. In finance, AI is being used for fraud detection, algorithmic trading, and risk assessment. Financial institutions leverage AI to analyze vast amounts of transaction data in real time, identifying suspicious patterns that could indicate fraudulent activity. AI-driven trading systems use predictive models to make high-frequency trading decisions, maximizing profits while minimizing risks.

The automotive industry is experiencing a revolution with AI-powered autonomous vehicles. Companies like Tesla, Waymo, and Uber are developing self-driving cars that use AI algorithms to navigate roads, detect obstacles, and make real-time driving decisions. These vehicles rely on a combination of computer vision, sensor fusion, and deep learning to operate safely. AI is also transforming the entertainment industry by enhancing content recommendations on streaming platforms like Netflix and Spotify. By analyzing user preferences and behavior, AI algorithms personalize content suggestions, improving user engagement. Additionally, AI-generated art and music are pushing the boundaries of creativity, demonstrating that machines can contribute to artistic expression.

In education, AI is personalizing learning experiences by adapting instructional content to individual student needs. Intelligent tutoring systems assess student performance and provide targeted feedback, helping learners grasp complex concepts more effectively. AI-driven grading systems automate the evaluation of assignments and exams, reducing the burden on educators. AI’s impact on the job market is a topic of significant debate. While AI is automating repetitive and mundane tasks, it is also creating new job opportunities in fields such as data science, AI engineering, and robotics. However, concerns about job displacement persist, prompting discussions about the need for workforce reskilling and upskilling initiatives.

Ethical considerations surrounding AI are gaining prominence as its applications become more widespread. Issues such as bias in AI algorithms, data privacy concerns, and the potential for autonomous weapons have sparked debates about responsible AI development and regulation. Ensuring that AI systems are transparent, fair, and aligned with human values is a pressing challenge for policymakers and researchers. The future of AI holds immense possibilities, with ongoing research focusing on achieving artificial general intelligence (AGI) – machines capable of performing any intellectual task that a human can do. While AGI remains a distant goal, advancements in AI continue to push the boundaries of what is possible. From healthcare and finance to education and entertainment, AI is reshaping industries and redefining the way humans interact with technology.

As AI continues to evolve, collaboration between governments, businesses, and academia will be crucial in ensuring that its benefits are maximized while addressing potential risks. The responsible and ethical development of AI will determine its impact on society in the years to come. With continued innovation and thoughtful regulation, AI has the potential to enhance human capabilities, drive economic growth, and improve the quality of life for people around the world.

The history of human civilization is a vast and intricate tapestry woven with countless stories of innovation, conquest, culture, and transformation. From the earliest hunter-gatherer societies to the modern interconnected digital age, humanity has continuously evolved, adapting to new challenges and reshaping the world in the process. The study of history provides insight into the forces that have shaped societies, the achievements of past civilizations, and the lessons that inform the future.

The first humans emerged in Africa millions of years ago, gradually developing tools, language, and social structures that allowed them to thrive. The advent of agriculture around 10,000 BCE marked a significant turning point, leading to the formation of permanent settlements and the rise of early civilizations. The Sumerians in Mesopotamia, the Egyptians along the Nile, the Indus Valley civilization, and the early Chinese dynasties all played crucial roles in shaping human history. These civilizations developed writing systems, governance structures, and monumental architecture that laid the groundwork for future societies.

The classical era saw the rise of empires such as the Greeks and Romans, who made significant contributions to philosophy, science, and governance. Greek thinkers like Socrates, Plato, and Aristotle laid the foundation for Western philosophical thought, while Roman law and engineering influenced generations to come. The decline of the Roman Empire in the fifth century ushered in the Middle Ages, a period characterized by feudalism, religious influence, and cultural stagnation in Europe. Meanwhile, the Islamic Golden Age flourished, with scholars making advancements in mathematics, medicine, and astronomy.

The Renaissance, beginning in the 14th century, marked a resurgence of learning, art, and exploration. Thinkers like Leonardo da Vinci, Michelangelo, and Galileo propelled human knowledge forward. The Age of Exploration saw European powers expanding their reach, leading to the colonization of the Americas, the transatlantic slave trade, and the exchange of goods and ideas across continents. The Industrial Revolution of the 18th and 19th centuries further transformed society, introducing mechanized production, urbanization, and economic shifts that shaped the modern world.

The 20th century witnessed rapid technological advancements, world wars, and social movements that redefined global politics and human rights. The two World Wars led to the rise and fall of empires, the Cold War era, and the establishment of international organizations like the United Nations. The Civil Rights Movement, feminist waves, and decolonization movements brought greater awareness to issues of equality and justice. The digital revolution of the late 20th and early 21st centuries has created an interconnected world, with information accessible at the click of a button.

As humanity progresses into the future, new challenges such as climate change, technological ethics, and geopolitical tensions arise. The study of history reminds us that societies have overcome adversity through innovation and collaboration. By understanding the past, we can navigate the complexities of the present and build a more equitable and sustainable future. Human civilization is an ever-evolving story, and its next chapters will be shaped by the choices and actions of today’s generations.

"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([faqs])

# %%
len(tokenizer.word_index)
# Out:
# 651

# %%
input_sequences = []
for sentence in faqs.split('\n'):
  tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]

  for i in range(1,len(tokenized_sentence)):
    input_sequences.append(tokenized_sentence[:i+1])

# %%
input_sequences
# Out:
# [[73, 41],
#  [73, 41, 4],
#  [73, 41, 4, 8],
#  [73, 41, 4, 8, 74],
#  [73, 41, 4, 8, 74, 3],
#  [73, 41, 4, 8, 74, 3, 1],
#  [73, 41, 4, 8, 74, 3, 1, 75],
#  [73, 41, 4, 8, 74, 3, 1, 75, 166],
#  [73, 41, 4, 8, 74, 3, 1, 75, 166, 167],
#  [73, 41, 4, 8, 74, 3, 1, 75, 166, 167, 3],
#  [73, 41, 4, 8, 74, 3, 1, 75, 166, 167, 3, 1],
#  [73, 41, 4, 8, 74, 3, 1, 75, 166, 167, 3, 1, 42],
#  [73, 41, 4, 8, 74, 3, 1, 75, 166, 167, 3, 1, 42, 43],
#  [73, 41, 4, 8, 74, 3, 1, 75, 166, 167, 3, 1, 42, 43, 76],
#  [73, 41, 4, 8, 74, 3, 1, 75, 166, 167, 3, 1, 42, 43, 76, 22],
#  [73, 41, 4, 8, 74, 3, 1, 75, 166, 167, 3, 1, 42, 43, 76, 22, 77],
#  [73, 41, 4, 8, 74, 3, 1, 75, 166, 167, 3, 1, 42, 43, 76, 22, 77, 28],
#  [73, 41, 4, 8, 74, 3, 1, 75, 166, 167, 3, 1, 42, 43, 76, 22, 77, 28, 78],
#  [73, 41, 4, 8, 74, 3, 1, 75, 166, 167, 3, 1, 42, 43, 76, 22, 77, 28, 78, 7],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1,
#   202],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1,
#   202,
#   203],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1,
#   202,
#   203,
#   204],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1,
#   202,
#   203,
#   204,
#   6],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1,
#   202,
#   203,
#   204,
#   6,
#   205],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1,
#   202,
#   203,
#   204,
#   6,
#   205,
#   206],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1,
#   202,
#   203,
#   204,
#   6,
#   205,
#   206,
#   207],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1,
#   202,
#   203,
#   204,
#   6,
#   205,
#   206,
#   207,
#   208],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1,
#   202,
#   203,
#   204,
#   6,
#   205,
#   206,
#   207,
#   208,
#   6],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1,
#   202,
#   203,
#   204,
#   6,
#   205,
#   206,
#   207,
#   208,
#   6,
#   4],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1,
#   202,
#   203,
#   204,
#   6,
#   205,
#   206,
#   207,
#   208,
#   6,
#   4,
#   25],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1,
#   202,
#   203,
#   204,
#   6,
#   205,
#   206,
#   207,
#   208,
#   6,
#   4,
#   25,
#   31],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1,
#   202,
#   203,
#   204,
#   6,
#   205,
#   206,
#   207,
#   208,
#   6,
#   4,
#   25,
#   31,
#   4],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1,
#   202,
#   203,
#   204,
#   6,
#   205,
#   206,
#   207,
#   208,
#   6,
#   4,
#   25,
#   31,
#   4,
#   84],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1,
#   202,
#   203,
#   204,
#   6,
#   205,
#   206,
#   207,
#   208,
#   6,
#   4,
#   25,
#   31,
#   4,
#   84,
#   209],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1,
#   202,
#   203,
#   204,
#   6,
#   205,
#   206,
#   207,
#   208,
#   6,
#   4,
#   25,
#   31,
#   4,
#   84,
#   209,
#   13],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1,
#   202,
#   203,
#   204,
#   6,
#   205,
#   206,
#   207,
#   208,
#   6,
#   4,
#   25,
#   31,
#   4,
#   84,
#   209,
#   13,
#   210],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1,
#   202,
#   203,
#   204,
#   6,
#   205,
#   206,
#   207,
#   208,
#   6,
#   4,
#   25,
#   31,
#   4,
#   84,
#   209,
#   13,
#   210,
#   81],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1,
#   202,
#   203,
#   204,
#   6,
#   205,
#   206,
#   207,
#   208,
#   6,
#   4,
#   25,
#   31,
#   4,
#   84,
#   209,
#   13,
#   210,
#   81,
#   2],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1,
#   202,
#   203,
#   204,
#   6,
#   205,
#   206,
#   207,
#   208,
#   6,
#   4,
#   25,
#   31,
#   4,
#   84,
#   209,
#   13,
#   210,
#   81,
#   2,
#   211],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1,
#   202,
#   203,
#   204,
#   6,
#   205,
#   206,
#   207,
#   208,
#   6,
#   4,
#   25,
#   31,
#   4,
#   84,
#   209,
#   13,
#   210,
#   81,
#   2,
#   211,
#   212],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1,
#   202,
#   203,
#   204,
#   6,
#   205,
#   206,
#   207,
#   208,
#   6,
#   4,
#   25,
#   31,
#   4,
#   84,
#   209,
#   13,
#   210,
#   81,
#   2,
#   211,
#   212,
#   14],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1,
#   202,
#   203,
#   204,
#   6,
#   205,
#   206,
#   207,
#   208,
#   6,
#   4,
#   25,
#   31,
#   4,
#   84,
#   209,
#   13,
#   210,
#   81,
#   2,
#   211,
#   212,
#   14,
#   213],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1,
#   202,
#   203,
#   204,
#   6,
#   205,
#   206,
#   207,
#   208,
#   6,
#   4,
#   25,
#   31,
#   4,
#   84,
#   209,
#   13,
#   210,
#   81,
#   2,
#   211,
#   212,
#   14,
#   213,
#   85],
#  [73,
#   41,
#   4,
#   8,
#   74,
#   3,
#   1,
#   75,
#   166,
#   167,
#   3,
#   1,
#   42,
#   43,
#   76,
#   22,
#   77,
#   28,
#   78,
#   7,
#   168,
#   169,
#   6,
#   44,
#   170,
#   5,
#   171,
#   45,
#   172,
#   173,
#   3,
#   174,
#   79,
#   4,
#   175,
#   5,
#   1,
#   176,
#   3,
#   10,
#   41,
#   6,
#   29,
#   177,
#   80,
#   5,
#   178,
#   46,
#   9,
#   179,
#   180,
#   10,
#   181,
#   18,
#   11,
#   12,
#   81,
#   182,
#   183,
#   2,
#   184,
#   82,
#   1,
#   185,
#   3,
#   4,
#   23,
#   47,
#   186,
#   187,
#   5,
#   1,
#   188,
#   30,
#   24,
#   189,
#   190,
#   19,
#   191,
#   83,
#   2,
#   192,
#   193,
#   48,
#   1,
#   194,
#   195,
#   16,
#   1,
#   196,
#   197,
#   198,
#   13,
#   1,
#   83,
#   199,
#   2,
#   200,
#   201,
#   3,
#   1,
#   202,
#   203,
#   204,
#   6,
#   205,
#   206,
#   207,
#   208,
#   6,
#   4,
#   25,
#   31,
#   4,
#   84,
#   209,
#   13,
#   210,
#   81,
#   2,
#   211,
#   212,
#   14,
#   213,
#   85,
#   5],
#  [73,
#   41,
#   4,
#   8,
#   74,
# ...
#   9,
#   491,
#   80,
#   5,
#   492,
#   1,
#   88,
#   3,
#   493,
#   143,
#   494,
#   495,
#   496,
#   50,
#   7,
#   60,
#   497,
#   498,
#   153,
#   5,
#   1,
#   499,
#   3,
#   500,
#   501,
#   2,
#   1,
#   72,
#   3,
#   31,
#   71,
#   1,
#   502,
#   6,
#   503,
#   1,
#   504,
#   505,
#   1,
#   506,
#   1,
#   507,
#   508,
#   68,
#   2,
#   1,
#   31,
#   509,
#   510,
#   511,
#   512,
#   138,
#   513],
#  [1,
#   484,
#   136,
#   485,
#   6,
#   486,
#   487,
#   3,
#   140,
#   488,
#   489,
#   117,
#   490,
#   52,
#   2,
#   151,
#   152,
#   9,
#   491,
#   80,
#   5,
#   492,
#   1,
#   88,
#   3,
#   493,
#   143,
#   494,
#   495,
#   496,
#   50,
#   7,
#   60,
#   497,
#   498,
#   153,
#   5,
#   1,
#   499,
#   3,
#   500,
#   501,
#   2,
#   1,
#   72,
#   3,
#   31,
#   71,
#   1,
#   502,
#   6,
#   503,
#   1,
#   504,
#   505,
#   1,
#   506,
#   1,
#   507,
#   508,
#   68,
#   2,
#   1,
#   31,
#   509,
#   510,
#   511,
#   512,
#   138,
#   513,
#   6],
#  [1,
#   484,
#   136,
#   485,
#   6,
#   486,
#   487,
#   3,
#   140,
#   488,
#   489,
#   117,
#   490,
#   52,
#   2,
#   151,
#   152,
#   9,
#   491,
#   80,
#   5,
#   492,
#   1,
#   88,
#   3,
#   493,
#   143,
#   494,
#   495,
#   496,
#   50,
#   7,
#   60,
#   497,
#   498,
#   153,
#   5,
#   1,
#   499,
#   3,
#   500,
#   501,
#   2,
#   1,
#   72,
#   3,
#   31,
#   71,
#   1,
#   502,
#   6,
#   503,
#   1,
#   504,
#   505,
#   1,
#   506,
#   1,
#   507,
#   508,
#   68,
#   2,
#   1,
#   31,
#   509,
#   510,
#   511,
#   512,
#   138,
#   513,
#   6,
#   514],
#  [1,
#   484,
#   136,
#   485,
#   6,
#   486,
#   487,
#   3,
#   140,
#   488,
#   489,
#   117,
#   490,
#   52,
#   2,
#   151,
#   152,
#   9,
#   491,
#   80,
#   5,
#   492,
#   1,
#   88,
#   3,
#   493,
#   143,
#   494,
#   495,
#   496,
#   50,
#   7,
#   60,
#   497,
#   498,
#   153,
#   5,
#   1,
#   499,
#   3,
#   500,
#   501,
#   2,
#   1,
#   72,
#   3,
#   31,
#   71,
#   1,
#   502,
#   6,
#   503,
#   1,
#   504,
#   505,
#   1,
#   506,
#   1,
#   507,
#   508,
#   68,
#   2,
#   1,
#   31,
#   509,
#   510,
#   511,
#   512,
#   138,
#   513,
#   6,
#   514,
#   10],
#  [1,
#   484,
#   136,
#   485,
#   6,
#   486,
#   487,
#   3,
#   140,
#   488,
#   489,
#   117,
#   490,
#   52,
#   2,
#   151,
#   152,
#   9,
#   491,
#   80,
#   5,
#   492,
#   1,
#   88,
#   3,
#   493,
#   143,
#   494,
#   495,
#   496,
#   50,
#   7,
#   60,
#   497,
#   498,
#   153,
#   5,
#   1,
#   499,
#   3,
#   500,
#   501,
#   2,
#   1,
#   72,
#   3,
#   31,
#   71,
#   1,
#   502,
#   6,
#   503,
#   1,
#   504,
#   505,
#   1,
#   506,
#   1,
#   507,
#   508,
#   68,
#   2,
#   1,
#   31,
#   509,
#   510,
#   511,
#   512,
#   138,
#   513,
#   6,
#   514,
#   10,
#   25],
#  [1,
#   484,
#   136,
#   485,
#   6,
#   486,
#   487,
#   3,
#   140,
#   488,
#   489,
#   117,
#   490,
#   52,
#   2,
#   151,
#   152,
#   9,
#   491,
#   80,
#   5,
#   492,
#   1,
#   88,
#   3,
#   493,
#   143,
#   494,
#   495,
#   496,
#   50,
#   7,
#   60,
#   497,
#   498,
#   153,
#   5,
#   1,
#   499,
#   3,
#   500,
#   501,
#   2,
#   1,
#   72,
#   3,
#   31,
#   71,
#   1,
#   502,
#   6,
#   503,
#   1,
#   504,
#   505,
#   1,
#   506,
#   1,
#   507,
#   508,
#   68,
#   2,
#   1,
#   31,
#   509,
#   510,
#   511,
#   512,
#   138,
#   513,
#   6,
#   514,
#   10,
#   25,
#   33],
#  [1,
#   484,
#   136,
#   485,
#   6,
#   486,
#   487,
#   3,
#   140,
#   488,
#   489,
#   117,
#   490,
#   52,
#   2,
#   151,
#   152,
#   9,
#   491,
#   80,
#   5,
#   492,
#   1,
#   88,
#   3,
#   493,
#   143,
#   494,
#   495,
#   496,
#   50,
#   7,
#   60,
#   497,
#   498,
#   153,
#   5,
#   1,
#   499,
#   3,
#   500,
#   501,
#   2,
#   1,
#   72,
#   3,
#   31,
#   71,
#   1,
#   502,
#   6,
#   503,
#   1,
#   504,
#   505,
#   1,
#   506,
#   1,
#   507,
#   508,
#   68,
#   2,
#   1,
#   31,
#   509,
#   510,
#   511,
#   512,
#   138,
#   513,
#   6,
#   514,
#   10,
#   25,
#   33,
#   71],
#  [1,
#   484,
#   136,
#   485,
#   6,
#   486,
#   487,
#   3,
#   140,
#   488,
#   489,
#   117,
#   490,
#   52,
#   2,
#   151,
#   152,
#   9,
#   491,
#   80,
#   5,
#   492,
#   1,
#   88,
#   3,
#   493,
#   143,
#   494,
#   495,
#   496,
#   50,
#   7,
#   60,
#   497,
#   498,
#   153,
#   5,
#   1,
#   499,
#   3,
#   500,
#   501,
#   2,
#   1,
#   72,
#   3,
#   31,
#   71,
#   1,
#   502,
#   6,
#   503,
#   1,
#   504,
#   505,
#   1,
#   506,
#   1,
#   507,
#   508,
#   68,
#   2,
#   1,
#   31,
#   509,
#   510,
#   511,
#   512,
#   138,
#   513,
#   6,
#   514,
#   10,
#   25,
#   33,
#   71,
#   515],
#  [1,
#   484,
#   136,
#   485,
#   6,
#   486,
#   487,
#   3,
#   140,
#   488,
#   489,
#   117,
#   490,
#   52,
#   2,
#   151,
#   152,
#   9,
#   491,
#   80,
#   5,
#   492,
#   1,
#   88,
#   3,
#   493,
#   143,
#   494,
#   495,
#   496,
#   50,
#   7,
#   60,
#   497,
#   498,
#   153,
#   5,
#   1,
#   499,
#   3,
#   500,
#   501,
#   2,
#   1,
#   72,
#   3,
#   31,
#   71,
#   1,
#   502,
#   6,
#   503,
#   1,
#   504,
#   505,
#   1,
#   506,
#   1,
#   507,
#   508,
#   68,
#   2,
#   1,
#   31,
#   509,
#   510,
#   511,
#   512,
#   138,
#   513,
#   6,
#   514,
#   10,
#   25,
#   33,
#   71,
#   515,
#   516],
#  [1,
#   484,
#   136,
#   485,
#   6,
#   486,
#   487,
#   3,
#   140,
#   488,
#   489,
#   117,
#   490,
#   52,
#   2,
#   151,
#   152,
#   9,
#   491,
#   80,
#   5,
#   492,
#   1,
#   88,
#   3,
#   493,
#   143,
#   494,
#   495,
#   496,
#   50,
#   7,
#   60,
#   497,
#   498,
#   153,
#   5,
#   1,
#   499,
#   3,
#   500,
#   501,
#   2,
#   1,
#   72,
#   3,
#   31,
#   71,
#   1,
#   502,
#   6,
#   503,
#   1,
#   504,
#   505,
#   1,
#   506,
#   1,
#   507,
#   508,
#   68,
#   2,
#   1,
#   31,
#   509,
#   510,
#   511,
#   512,
#   138,
#   513,
#   6,
#   514,
#   10,
#   25,
#   33,
#   71,
#   515,
#   516,
#   14],
#  [1,
#   484,
#   136,
#   485,
#   6,
#   486,
#   487,
#   3,
#   140,
#   488,
#   489,
#   117,
#   490,
#   52,
#   2,
#   151,
#   152,
#   9,
#   491,
#   80,
#   5,
#   492,
#   1,
#   88,
#   3,
#   493,
#   143,
#   494,
#   495,
#   496,
#   50,
#   7,
#   60,
#   497,
#   498,
#   153,
#   5,
#   1,
#   499,
#   3,
#   500,
#   501,
#   2,
#   1,
#   72,
#   3,
#   31,
#   71,
#   1,
#   502,
#   6,
#   503,
#   1,
#   504,
#   505,
#   1,
#   506,
#   1,
#   507,
#   508,
#   68,
#   2,
#   1,
#   31,
#   509,
#   510,
#   511,
#   512,
#   138,
#   513,
#   6,
#   514,
#   10,
#   25,
#   33,
#   71,
#   515,
#   516,
#   14,
#   154],
#  [1,
#   484,
#   136,
#   485,
#   6,
#   486,
#   487,
#   3,
#   140,
#   488,
#   489,
#   117,
#   490,
#   52,
#   2,
#   151,
#   152,
#   9,
#   491,
#   80,
#   5,
#   492,
#   1,
#   88,
#   3,
#   493,
#   143,
#   494,
#   495,
#   496,
#   50,
#   7,
#   60,
#   497,
#   498,
#   153,
#   5,
#   1,
#   499,
#   3,
#   500,
#   501,
#   2,
#   1,
#   72,
#   3,
#   31,
#   71,
#   1,
#   502,
#   6,
#   503,
#   1,
#   504,
#   505,
#   1,
#   506,
#   1,
#   507,
#   508,
#   68,
#   2,
#   1,
#   31,
#   509,
#   510,
#   511,
#   512,
#   138,
#   513,
#   6,
#   514,
#   10,
#   25,
#   33,
#   71,
#   515,
#   516,
#   14,
#   154,
#   152],
#  [1,
#   484,
#   136,
#   485,
#   6,
#   486,
#   487,
#   3,
#   140,
#   488,
#   489,
#   117,
#   490,
#   52,
#   2,
#   151,
#   152,
#   9,
#   491,
#   80,
#   5,
#   492,
#   1,
#   88,
#   3,
#   493,
#   143,
#   494,
#   495,
#   496,
#   50,
#   7,
#   60,
#   497,
#   498,
#   153,
#   5,
#   1,
#   499,
#   3,
#   500,
#   501,
#   2,
#   1,
#   72,
#   3,
#   31,
#   71,
#   1,
#   502,
#   6,
#   503,
#   1,
#   504,
#   505,
#   1,
#   506,
#   1,
#   507,
#   508,
#   68,
#   2,
#   1,
#   31,
#   509,
#   510,
#   511,
#   512,
#   138,
#   513,
#   6,
#   514,
#   10,
#   25,
#   33,
#   71,
#   515,
#   516,
#   14,
#   154,
#   152,
#   2],
#  [1,
#   484,
#   136,
#   485,
#   6,
#   486,
#   487,
#   3,
#   140,
#   488,
#   489,
#   117,
#   490,
#   52,
#   2,
#   151,
#   152,
#   9,
#   491,
#   80,
#   5,
#   492,
#   1,
#   88,
#   3,
#   493,
#   143,
#   494,
#   495,
#   496,
#   50,
#   7,
#   60,
#   497,
#   498,
#   153,
#   5,
#   1,
#   499,
#   3,
#   500,
#   501,
#   2,
#   1,
#   72,
#   3,
#   31,
#   71,
#   1,
#   502,
#   6,
#   503,
#   1,
#   504,
#   505,
#   1,
#   506,
#   1,
#   507,
#   508,
#   68,
#   2,
#   1,
#   31,
#   509,
#   510,
#   511,
#   512,
#   138,
#   513,
#   6,
#   514,
#   10,
#   25,
#   33,
#   71,
#   515,
#   516,
#   14,
#   154,
#   152,
#   2,
#   517],
#  [1,
#   484,
#   136,
#   485,
#   6,
#   486,
#   487,
#   3,
#   140,
#   488,
#   489,
#   117,
#   490,
#   52,
#   2,
#   151,
#   152,
#   9,
#   491,
#   80,
#   5,
#   492,
#   1,
#   88,
#   3,
#   493,
#   143,
#   494,
#   495,
#   496,
#   50,
#   7,
#   60,
#   497,
#   498,
#   153,
#   5,
#   1,
#   499,
#   3,
#   500,
#   501,
#   2,
#   1,
#   72,
#   3,
#   31,
#   71,
#   1,
#   502,
#   6,
#   503,
#   1,
#   504,
#   505,
#   1,
#   506,
#   1,
#   507,
#   508,
#   68,
#   2,
#   1,
#   31,
#   509,
#   510,
#   511,
#   512,
#   138,
#   513,
#   6,
#   514,
#   10,
#   25,
#   33,
#   71,
#   515,
#   516,
#   14,
#   154,
#   152,
#   2,
#   517,
#   518],
#  [1,
#   484,
#   136,
#   485,
#   6,
#   486,
#   487,
#   3,
#   140,
#   488,
#   489,
#   117,
#   490,
#   52,
#   2,
#   151,
#   152,
#   9,
#   491,
#   80,
#   5,
#   492,
#   1,
#   88,
#   3,
#   493,
#   143,
#   494,
#   495,
#   496,
#   50,
#   7,
#   60,
#   497,
#   498,
#   153,
#   5,
#   1,
#   499,
#   3,
#   500,
#   501,
#   2,
#   1,
#   72,
#   3,
#   31,
#   71,
#   1,
#   502,
#   6,
#   503,
#   1,
#   504,
#   505,
#   1,
#   506,
#   1,
#   507,
#   508,
#   68,
#   2,
#   1,
#   31,
#   509,
#   510,
#   511,
#   512,
#   138,
#   513,
#   6,
#   514,
#   10,
#   25,
#   33,
#   71,
#   515,
#   516,
#   14,
#   154,
#   152,
#   2,
#   517,
#   518,
#   9],
#  [1,
#   484,
#   136,
#   485,
#   6,
#   486,
#   487,
#   3,
#   140,
#   488,
#   489,
#   117,
#   490,
#   52,
#   2,
#   151,
#   152,
#   9,
#   491,
#   80,
#   5,
#   492,
#   1,
#   88,
#   3,
#   493,
#   143,
#   494,
#   495,
#   496,
#   50,
#   7,
#   60,
#   497,
#   498,
#   153,
#   5,
#   1,
#   499,
#   3,
#   500,
#   501,
#   2,
#   1,
#   72,
#   3,
#   31,
#   71,
#   1,
#   502,
#   6,
#   503,
#   1,
#   504,
#   505,
#   1,
#   506,
#   1,
#   507,
#   508,
#   68,
#   2,
#   1,
#   31,
#   509,
#   510,
#   511,
#   512,
#   138,
#   513,
#   6,
#   514,
#   10,
#   25,
#   33,
#   71,
#   515,
#   516,
#   14,
#   154,
#   152,
#   2,
#   517,
#   518,
#   9,
#   48],
#  [1,
#   484,
#   136,
#   485,
#   6,
#   486,
#   487,
#   3,
#   140,
#   488,
#   489,
#   117,
#   490,
#   52,
#   2,
#   151,
#   152,
#   9,
#   491,
#   80,
#   5,
#   492,
#   1,
#   88,
#   3,
#   493,
#   143,
#   494,
#   495,
#   496,
#   50,
#   7,
#   60,
#   497,
#   498,
#   153,
#   5,
#   1,
#   499,
#   3,
#   500,
#   501,
#   2,
#   1,
#   72,
#   3,
#   31,
#   71,
#   1,
#   502,
#   6,
#   503,
#   1,
#   504,
#   505,
#   1,
#   506,
#   1,
#   507,
#   508,
#   68,
#   2,
#   1,
#   31,
#   509,
#   510,
#   511,
#   512,
#   138,
#   513,
#   6,
#   514,
#   10,
#   25,
#   33,
#   71,
#   515,
#   516,
#   14,
#   154,
#   152,
#   2,
#   517,
#   518,
#   9,
#   48,
#   1],
#  [1,
#   484,
#   136,
#   485,
#   6,
#   486,
#   487,
#   3,
#   140,
#   488,
#   489,
#   117,
#   490,
#   52,
#   2,
#   151,
#   152,
#   9,
#   491,
#   80,
#   5,
#   492,
#   1,
#   88,
#   3,
#   493,
#   143,
#   494,
#   495,
#   496,
#   50,
#   7,
#   60,
#   497,
#   498,
#   153,
#   5,
#   1,
#   499,
#   3,
#   500,
#   501,
#   2,
#   1,
#   72,
#   3,
#   31,
#   71,
#   1,
#   502,
#   6,
#   503,
#   1,
#   504,
#   505,
#   1,
#   506,
#   1,
#   507,
#   508,
#   68,
#   2,
#   1,
#   31,
#   509,
#   510,
#   511,
#   512,
#   138,
#   513,
#   6,
#   514,
#   10,
#   25,
#   33,
#   71,
#   515,
#   516,
#   14,
#   154,
#   152,
#   2,
#   517,
#   518,
#   9,
#   48,
#   1,
#   519],
#  [1,
#   484,
#   136,
#   485,
#   6,
#   486,
#   487,
#   3,
#   140,
#   488,
#   489,
#   117,
#   490,
#   52,
#   2,
#   151,
#   152,
#   9,
#   491,
#   80,
#   5,
#   492,
#   1,
#   88,
#   3,
#   493,
#   143,
#   494,
#   495,
#   496,
#   50,
#   7,
#   60,
#   497,
#   498,
#   153,
#   5,
#   1,
#   499,
#   3,
#   500,
#   501,
#   2,
#   1,
#   72,
#   3,
#   31,
#   71,
#   1,
#   502,
#   6,
#   503,
#   1,
#   504,
#   505,
#   1,
#   506,
#   1,
#   507,
#   508,
#   68,
#   2,
#   1,
#   31,
#   509,
#   510,
#   511,
#   512,
#   138,
#   513,
#   6,
#   514,
#   10,
#   25,
#   33,
#   71,
#   515,
#   516,
#   14,
#   154,
#   152,
#   2,
#   517,
#   518,
#   9,
#   48,
#   1,
#   519,
#   16],
#  [1,
#   484,
#   136,
#   485,
#   6,
#   486,
#   487,
#   3,
#   140,
#   488,
#   489,
#   117,
#   490,
#   52,
#   2,
#   151,
#   152,
#   9,
#   491,
#   80,
#   5,
#   492,
#   1,
#   88,
#   3,
#   493,
#   143,
#   494,
#   495,
#   496,
#   50,
#   7,
#   60,
#   497,
#   498,
#   153,
#   5,
#   1,
#   499,
#   3,
#   500,
#   501,
#   2,
#   1,
#   72,
#   3,
#   31,
#   71,
#   1,
#   502,
#   6,
#   503,
#   1,
#   504,
#   505,
#   1,
#   506,
#   1,
#   507,
#   508,
#   68,
#   2,
#   1,
#   31,
#   509,
#   510,
#   511,
#   512,
#   138,
#   513,
#   6,
#   514,
#   10,
#   25,
#   33,
#   71,
#   515,
#   516,
#   14,
#   154,
#   152,
#   2,
#   517,
#   518,
#   9,
#   48,
#   1,
#   519,
#   16,
#   27],
#  [1,
#   484,
#   136,
#   485,
#   6,
#   486,
#   487,
#   3,
#   140,
#   488,
#   489,
#   117,
#   490,
#   52,
#   2,
#   151,
#   152,
#   9,
#   491,
#   80,
#   5,
#   492,
#   1,
#   88,
#   3,
#   493,
#   143,
#   494,
#   495,
#   496,
#   50,
#   7,
#   60,
#   497,
#   498,
#   153,
#   5,
#   1,
#   499,
#   3,
#   500,
#   501,
#   2,
#   1,
#   72,
#   3,
#   31,
#   71,
#   1,
#   502,
#   6,
#   503,
#   1,
#   504,
#   505,
#   1,
#   506,
#   1,
#   507,
#   508,
#   68,
#   2,
#   1,
#   31,
#   509,
#   510,
#   511,
#   512,
#   138,
#   513,
#   6,
#   514,
#   10,
#   25,
#   33,
#   71,
#   515,
#   516,
#   14,
#   154,
#   152,
#   2,
#   517,
#   518,
#   9,
#   48,
#   1,
#   519,
#   16,
#   27,
#   40],
#  [1, 520],
#  [1, 520, 43],
#  [1, 520, 43, 155],
#  [1, 520, 43, 155, 1],
#  [1, 520, 43, 155, 1, 72],
#  [1, 520, 43, 155, 1, 72, 3],
#  [1, 520, 43, 155, 1, 72, 3, 156],
#  [1, 520, 43, 155, 1, 72, 3, 156, 18],
#  [1, 520, 43, 155, 1, 72, 3, 156, 18, 11],
#  [1, 520, 43, 155, 1, 72, 3, 156, 18, 11, 1],
#  [1, 520, 43, 155, 1, 72, 3, 156, 18, 11, 1, 521],
#  [1, 520, 43, 155, 1, 72, 3, 156, 18, 11, 1, 521, 2],
#  [1, 520, 43, 155, 1, 72, 3, 156, 18, 11, 1, 521, 2, 522],
#  [1, 520, 43, 155, 1, 72, 3, 156, 18, 11, 1, 521, 2, 522, 523],
#  [1, 520, 43, 155, 1, 72, 3, 156, 18, 11, 1, 521, 2, 522, 523, 524],
#  [1, 520, 43, 155, 1, 72, 3, 156, 18, 11, 1, 521, 2, 522, 523, 524, 60],
#  [1, 520, 43, 155, 1, 72, 3, 156, 18, 11, 1, 521, 2, 522, 523, 524, 60, 525],
#  [1,
#   520,
#   43,
#   155,
#   1,
#   72,
#   3,
#   156,
#   18,
#   11,
#   1,
#   521,
#   2,
#   522,
#   523,
#   524,
#   60,
#   525,
#   5],
#  [1,
#   520,
#   43,
#   155,
#   1,
#   72,
#   3,
#   156,
#   18,
#   11,
#   1,
#   521,
#   2,
#   522,
#   523,
#   524,
#   60,
#   525,
#   5,
#   526],
#  [1,
#   520,
#   43,
#   155,
#   1,
#   72,
#   3,
#   156,
#   18,
#   11,
#   1,
#   521,
#   2,
#   522,
#   523,
#   524,
#   60,
#   525,
#   5,
#   526,
#   44],
#  [1,
#   520,
#   43,
#   155,
#   1,
#   72,
#   3,
#   156,
#   18,
#   11,
#   1,
#   521,
#   2,
#   522,
#   523,
#   524,
#   60,
#   525,
#   5,
#   526,
#   44,
#   2],
#  [1,
#   520,
#   43,
#   155,
#   1,
#   72,
#   3,
#   156,
#   18,
#   11,
#   1,
#   521,
#   2,
#   522,
#   523,
#   524,
#   60,
#   525,
#   5,
#   526,
#   44,
#   2,
#   154],
#  [1,
#   520,
#   43,
#   155,
#   1,
#   72,
#   3,
#   156,
#   18,
#   11,
#   1,
#   521,
#   2,
#   522,
#   523,
#   524,
#   60,
#   525,
#   5,
#   526,
#   44,
#   2,
#   154,
#   527],
#  [1,
#   520,
#   43,
#   155,
#   1,
#   72,
#   3,
#   156,
#   18,
#   11,
#   1,
#   521,
#   2,
#   522,
#   523,
#   524,
#   60,
#   525,
#   5,
#   526,
#   44,
#   2,
#   154,
#   527,
#   157],
#  [1,
#   520,
#   43,
#   155,
#   1,
#   72,
#   3,
#   156,
#   18,
#   11,
#   1,
#   521,
#   2,
#   522,
#   523,
#   524,
#   60,
#   525,
#   5,
#   526,
#   44,
#   2,
#   154,
#   527,
#   157,
#   19],
#  [1,
#   520,
#   43,
#   155,
#   1,
#   72,
#   3,
#   156,
#   18,
#   11,
#   1,
#   521,
#   2,
#   522,
#   523,
#   524,
#   60,
#   525,
#   5,
#   526,
#   44,
#   2,
#   154,
#   527,
#   157,
#   19,
#   528],
#  [1,
#   520,
#   43,
#   155,
#   1,
#   72,
#   3,
#   156,
#   18,
#   11,
#   1,
#   521,
#   2,
#   522,
#   523,
#   524,
#   60,
#   525,
#   5,
#   526,
#   44,
#   2,
#   154,
#   527,
#   157,
#   19,
#   528,
#   529],
#  [1,
#   520,
#   43,
#   155,
#   1,
#   72,
#   3,
#   156,
#   18,
#   11,
#   1,
#   521,
#   2,
#   522,
#   523,
#   524,
#   60,
#   525,
#   5,
#   526,
#   44,
#   2,
#   154,
#   527,
#   157,
#   19,
#   528,
#   529,
#   2],
#  [1,
#   520,
#   43,
#   155,
#   1,
#   72,
#   3,
#   156,
#   18,
#   11,
#   1,
#   521,
#   2,
#   522,
#   523,
#   524,
#   60,
#   525,
#   5,
#   526,
#   44,
#   2,
#   154,
#   527,
#   157,
#   19,
#   528,
#   529,
#   2,
#   530],
#  [1,
#   520,
#   43,
#   155,
#   1,
#   72,
#   3,
#   156,
#   18,
#   11,
#   1,
#   521,
#   2,
#   522,
#   523,
#   524,
#   60,
#   525,
#   5,
#   526,
#   44,
#   2,
#   154,
#   527,
#   157,
#   19,
#   528,
#   529,
#   2,
#   530,
#   48],
#  [1,
#   520,
#   43,
#   155,
#   1,
#   72,
#   3,
#   156,
#   18,
#   11,
#   1,
#   521,
#   2,
#   522,
#   523,
#   524,
#   60,
#   525,
#   5,
#   526,
#   44,
#   2,
#   154,
#   527,
#   157,
#   19,
#   528,
#   529,
#   2,
#   530,
#   48,
#   1],
#  [1,
#   520,
#   43,
#   155,
#   1,
#   72,
#   3,
#   156,
#   18,
#   11,
#   1,
#   521,
#   2,
#   522,
#   523,
#   524,
#   60,
#   525,
#   5,
#   526,
#   44,
#   2,
#   154,
#   527,
#   157,
#   19,
#   528,
#   529,
#   2,
#   530,
#   48,
#   1,
#   531],
#  [1,
#   520,
#   43,
#   155,
#   1,
#   72,
#   3,
#   156,
#   18,
#   11,
#   1,
#   521,
#   2,
#   522,
#   523,
#   524,
#   60,
#   525,
#   5,
#   526,
#   44,
#   2,
#   154,
#   527,
#   157,
#   19,
#   528,
#   529,
#   2,
#   530,
#   48,
#   1,
#   531,
#   16],
#  [1,
#   520,
#   43,
#   155,
#   1,
#   72,
#   3,
#   156,
#   18,
#   11,
#   1,
#   521,
#   2,
#   522,
#   523,
#   524,
#   60,
#   525,
#   5,
#   526,
#   44,
#   2,
#   154,
#   527,
#   157,
#   19,
#   528,
#   529,
#   2,
#   530,
#   48,
#   1,
#   531,
#   16,
#   532],
#  [1,
#   520,
#   43,
#   155,
#   1,
#   72,
#   3,
#   156,
#   18,
#   11,
#   1,
#   521,
#   2,
#   522,
#   523,
#   524,
#   60,
#   525,
#   5,
#   526,
#   44,
#   2,
#   154,
#   527,
#   157,
#   19,
#   528,
#   529,
#   2,
#   530,
#   48,
#   1,
#   531,
#   16,
#   532,
#   533],
#  [1,
#   520,
#   43,
#   155,
#   1,
#   72,
#   3,
#   156,
#   18,
#   11,
#   1,
#   521,
#   2,
#   522,
#   523,
#   524,
#   60,
#   525,
#   5,
#   526,
#   44,
#   2,
#   154,
#   527,
#   157,
#   19,
#   528,
#   529,
#   2,
#   530,
#   48,
#   1,
#   531,
#   16,
#   532,
#   533,
#   534],
#  [1,
#   520,
#   43,
#   155,
#   1,
#   72,
#   3,
#   156,
#   18,
#   11,
#   1,
#   521,
#   2,
#   522,
#   523,
#   524,
#   60,
#   525,
#   5,
#   526,
#   44,
#   2,
#   154,
#   527,
#   157,
#   19,
#   528,
#   529,
#   2,
#   530,
#   48,
#   1,
#   531,
#   16,
#   532,
#   533,
#   534,
#   26],
#  [1,
#   520,
#   43,
#   155,
#   1,
#   72,
#   3,
#   156,
#   18,
#   11,
#   1,
#   521,
#   2,
#   522,
#   523,
#   524,
#   60,
#   525,
#   5,
#   526,
#   44,
#   2,
#   154,
#   527,
#   157,
#   19,
#   528,
#   529,
#   2,
#   530,
#   48,
#   1,
#   531,
#   16,
#   532,
#   533,
#   534,
#   26,
#   158],
#  [1,
#   520,
#   43,
#   155,
#   1,
#   72,
#   3,
#   156,
#   18,
#   11,
#   1,
#   521,
#   2,
#   522,
#   523,
#   524,
#   60,
#   525,
#   5,
#   526,
#   44,
#   2,
#   154,
#   527,
#   157,
#   19,
#   528,
#   529,
#   2,
#   530,
#   48,
#   1,
#   531,
#   16,
#   532,
#   533,
#   534,
#   26,
#   158,
#   535],
#  [1,
#   520,
#   43,
#   155,
#   1,
#   72,
#   3,
#   156,
#   18,
#   11,
#   1,
#   521,
#   2,
#   522,
#   523,
#   524,
#   60,
#   525,
#   5,
#   526,
#   44,
#   2,
#   154,
#   527,
#   157,
#   19,
#   528,
#   529,
#   2,
#   530,
#   48,
#   1,
#   531,
#   16,
#   532,
#   533,
#   534,
#   26,
#   158,
#   535,
#   2],
#  ...]

# %%
max_len = max([len(x) for x in input_sequences])

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences, maxlen = max_len, padding='pre')

# %%
padded_input_sequences
# Out:
# array([[  0,   0,   0, ...,   0,  73,  41],
#        [  0,   0,   0, ...,  73,  41,   4],
#        [  0,   0,   0, ...,  41,   4,   8],
#        ...,
#        [  0,   0,   0, ...,   2, 650,   3],
#        [  0,   0,   0, ..., 650,   3, 651],
#        [  0,   0,   0, ...,   3, 651, 159]])

# %%
X = padded_input_sequences[:,:-1]

# %%
y = padded_input_sequences[:,-1]

# %%
X.shape
# Out:
# (1288, 173)

# %%
y.shape
# Out:
# (1288,)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y,num_classes=652)

# %%
y.shape
# Out:
# (1288, 652)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
model = Sequential()
model.add(Embedding(652, 100, input_length=173))
model.add(LSTM(150))
model.add(Dense(652, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                        ┃ Output Shape               ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)             │ ?                          │     0 (unbuilt) │
# ├─────────────────────────────────────┼────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                       │ ?                          │     0 (unbuilt) │
# ├─────────────────────────────────────┼────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                     │ ?                          │     0 (unbuilt) │
# └─────────────────────────────────────┴────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X,y,epochs=100)
# Out:
# Epoch 1/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 32s 519ms/step - accuracy: 0.0416 - loss: 6.3836
# Epoch 2/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 19s 465ms/step - accuracy: 0.0607 - loss: 5.8170
# Epoch 3/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 428ms/step - accuracy: 0.0548 - loss: 5.7961
# Epoch 4/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 17s 422ms/step - accuracy: 0.0639 - loss: 5.6757
# Epoch 5/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 431ms/step - accuracy: 0.0649 - loss: 5.6272
# Epoch 6/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 20s 483ms/step - accuracy: 0.0822 - loss: 5.5545
# Epoch 7/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 19s 465ms/step - accuracy: 0.0962 - loss: 5.3600
# Epoch 8/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 445ms/step - accuracy: 0.1148 - loss: 5.1936
# Epoch 9/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 20s 445ms/step - accuracy: 0.1261 - loss: 5.1184
# Epoch 10/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 21s 441ms/step - accuracy: 0.1354 - loss: 4.9034
# Epoch 11/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 431ms/step - accuracy: 0.1440 - loss: 4.7310
# Epoch 12/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 21s 435ms/step - accuracy: 0.1708 - loss: 4.4595
# Epoch 13/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 443ms/step - accuracy: 0.1822 - loss: 4.2842
# Epoch 14/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 430ms/step - accuracy: 0.1976 - loss: 4.0760
# Epoch 15/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 21s 431ms/step - accuracy: 0.2327 - loss: 3.8497
# Epoch 16/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 22s 462ms/step - accuracy: 0.2420 - loss: 3.7062
# Epoch 17/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 446ms/step - accuracy: 0.2858 - loss: 3.4890
# Epoch 18/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 0.3287 - loss: 3.3022
# Epoch 19/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - accuracy: 0.3337 - loss: 3.1267
# Epoch 20/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 277ms/step - accuracy: 0.3754 - loss: 2.9425
# Epoch 21/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 172ms/step - accuracy: 0.4482 - loss: 2.7503
# Epoch 22/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 167ms/step - accuracy: 0.4852 - loss: 2.5954
# Epoch 23/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 0.5555 - loss: 2.4522
# Epoch 24/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 0.5804 - loss: 2.2974
# Epoch 25/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 154ms/step - accuracy: 0.6380 - loss: 2.1592
# Epoch 26/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - accuracy: 0.6920 - loss: 1.9615
# Epoch 27/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 180ms/step - accuracy: 0.7447 - loss: 1.8264
# Epoch 28/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 215ms/step - accuracy: 0.7690 - loss: 1.7120
# Epoch 29/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 0.8231 - loss: 1.5993
# Epoch 30/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 0.8425 - loss: 1.4558
# Epoch 31/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 168ms/step - accuracy: 0.8477 - loss: 1.3620
# Epoch 32/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 167ms/step - accuracy: 0.9061 - loss: 1.2189
# Epoch 33/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 129ms/step - accuracy: 0.9108 - loss: 1.1555
# Epoch 34/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 0.9224 - loss: 1.0599
# Epoch 35/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 168ms/step - accuracy: 0.9447 - loss: 0.9156
# Epoch 36/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.9576 - loss: 0.8371
# Epoch 37/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 0.9635 - loss: 0.7907
# Epoch 38/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 0.9751 - loss: 0.7202
# Epoch 39/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - accuracy: 0.9716 - loss: 0.6609
# Epoch 40/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - accuracy: 0.9835 - loss: 0.5936
# Epoch 41/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - accuracy: 0.9846 - loss: 0.5565
# Epoch 42/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 196ms/step - accuracy: 0.9844 - loss: 0.5083
# Epoch 43/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.9907 - loss: 0.4638
# Epoch 44/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 163ms/step - accuracy: 0.9877 - loss: 0.4175
# Epoch 45/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 0.9914 - loss: 0.3936
# Epoch 46/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step - accuracy: 0.9882 - loss: 0.3631
# Epoch 47/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.9875 - loss: 0.3630
# Epoch 48/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 185ms/step - accuracy: 0.9944 - loss: 0.3260
# Epoch 49/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 174ms/step - accuracy: 0.9941 - loss: 0.3001
# Epoch 50/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - accuracy: 0.9929 - loss: 0.2771
# Epoch 51/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 164ms/step - accuracy: 0.9974 - loss: 0.2592
# Epoch 52/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - accuracy: 0.9920 - loss: 0.2442
# Epoch 53/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 137ms/step - accuracy: 0.9930 - loss: 0.2297
# Epoch 54/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 163ms/step - accuracy: 0.9929 - loss: 0.2189
# Epoch 55/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 0.9914 - loss: 0.2026
# Epoch 56/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 132ms/step - accuracy: 0.9950 - loss: 0.1909
# Epoch 57/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.9926 - loss: 0.1834
# Epoch 58/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 171ms/step - accuracy: 0.9903 - loss: 0.1728
# Epoch 59/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.9911 - loss: 0.1636
# Epoch 60/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 191ms/step - accuracy: 0.9927 - loss: 0.1520
# Epoch 61/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 236ms/step - accuracy: 0.9904 - loss: 0.1460
# Epoch 62/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.9873 - loss: 0.1411
# Epoch 63/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 168ms/step - accuracy: 0.9902 - loss: 0.1344
# Epoch 64/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 174ms/step - accuracy: 0.9932 - loss: 0.1230
# Epoch 65/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.9935 - loss: 0.1169
# Epoch 66/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - accuracy: 0.9901 - loss: 0.1181
# Epoch 67/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.9933 - loss: 0.1093
# Epoch 68/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 0.9953 - loss: 0.1006
# Epoch 69/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - accuracy: 0.9960 - loss: 0.0961
# Epoch 70/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - accuracy: 0.9971 - loss: 0.0913
# Epoch 71/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - accuracy: 0.9911 - loss: 0.0893
# Epoch 72/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 0.9868 - loss: 0.0885
# Epoch 73/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.9958 - loss: 0.0801
# Epoch 74/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - accuracy: 0.9917 - loss: 0.0818
# Epoch 75/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 0.9913 - loss: 0.0800
# Epoch 76/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - accuracy: 0.9969 - loss: 0.0707
# Epoch 77/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 0.9923 - loss: 0.0698
# Epoch 78/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 155ms/step - accuracy: 0.9948 - loss: 0.0658
# Epoch 79/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 205ms/step - accuracy: 0.9971 - loss: 0.0623
# Epoch 80/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 178ms/step - accuracy: 0.9930 - loss: 0.0642
# Epoch 81/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - accuracy: 0.9977 - loss: 0.0536
# Epoch 82/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 0.9931 - loss: 0.0598
# Epoch 83/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 133ms/step - accuracy: 0.9920 - loss: 0.0620
# Epoch 84/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 0.9914 - loss: 0.0625
# Epoch 85/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 134ms/step - accuracy: 0.9947 - loss: 0.0528
# Epoch 86/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.9927 - loss: 0.0531
# Epoch 87/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 229ms/step - accuracy: 0.9956 - loss: 0.0465
# Epoch 88/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 191ms/step - accuracy: 0.9920 - loss: 0.0550
# Epoch 89/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - accuracy: 0.9941 - loss: 0.0470
# Epoch 90/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.9958 - loss: 0.0422
# Epoch 91/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 153ms/step - accuracy: 0.9886 - loss: 0.0531
# Epoch 92/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 136ms/step - accuracy: 0.9938 - loss: 0.0428
# Epoch 93/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.9957 - loss: 0.0453
# Epoch 94/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - accuracy: 0.9932 - loss: 0.0429
# Epoch 95/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 0.9928 - loss: 0.0413
# Epoch 96/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step - accuracy: 0.9927 - loss: 0.0405
# Epoch 97/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.9961 - loss: 0.0380
# Epoch 98/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 168ms/step - accuracy: 0.9959 - loss: 0.0357
# Epoch 99/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 166ms/step - accuracy: 0.9912 - loss: 0.0399
# Epoch 100/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 126ms/step - accuracy: 0.9954 - loss: 0.0407

# %%
import time
import numpy as np
text = "what is the fee"

for i in range(10):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=56, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step
# what is the fee subset
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# what is the fee subset of
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# what is the fee subset of ai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# what is the fee subset of ai leverages
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# what is the fee subset of ai leverages statistical
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# what is the fee subset of ai leverages statistical techniques
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# what is the fee subset of ai leverages statistical techniques to
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# what is the fee subset of ai leverages statistical techniques to enable
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# what is the fee subset of ai leverages statistical techniques to enable machines
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# what is the fee subset of ai leverages statistical techniques to enable machines to

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'and': 2,
#  'of': 3,
#  'ai': 4,
#  'to': 5,
#  'in': 6,
#  'a': 7,
#  'is': 8,
#  'that': 9,
#  'human': 10,
#  'as': 11,
#  'learning': 12,
#  'on': 13,
#  'systems': 14,
#  'with': 15,
#  'for': 16,
#  'by': 17,
#  'such': 18,
#  'like': 19,
#  'world': 20,
#  'are': 21,
#  'has': 22,
#  'can': 23,
#  'century': 24,
#  'history': 25,
#  'while': 26,
#  'future': 27,
#  'from': 28,
#  'machines': 29,
#  '20th': 30,
#  'early': 31,
#  'development': 32,
#  'these': 33,
#  'machine': 34,
#  'data': 35,
#  'more': 36,
#  'driven': 37,
#  'algorithms': 38,
#  'its': 39,
#  'societies': 40,
#  'intelligence': 41,
#  'modern': 42,
#  'era': 43,
#  'science': 44,
#  'an': 45,
#  'tasks': 46,
#  'be': 47,
#  'laid': 48,
#  'real': 49,
#  'marked': 50,
#  'deep': 51,
#  'language': 52,
#  'autonomous': 53,
#  'user': 54,
#  'also': 55,
#  'trading': 56,
#  'revolution': 57,
#  'content': 58,
#  'job': 59,
#  'significant': 60,
#  'new': 61,
#  'about': 62,
#  'potential': 63,
#  'have': 64,
#  'advancements': 65,
#  'will': 66,
#  'innovation': 67,
#  'civilization': 68,
#  'age': 69,
#  'shaped': 70,
#  'civilizations': 71,
#  'rise': 72,
#  'artificial': 73,
#  'one': 74,
#  'most': 75,
#  'it': 76,
#  'evolved': 77,
#  'being': 78,
#  'life': 79,
#  'them': 80,
#  'reasoning': 81,
#  'making': 82,
#  'turing': 83,
#  'research': 84,
#  'led': 85,
#  'however': 86,
#  'complexities': 87,
#  'advent': 88,
#  'late': 89,
#  'could': 90,
#  'improve': 91,
#  'their': 92,
#  'performance': 93,
#  'way': 94,
#  'natural': 95,
#  'processing': 96,
#  'computer': 97,
#  'vision': 98,
#  'applications': 99,
#  'powered': 100,
#  'customer': 101,
#  'healthcare': 102,
#  'personalizing': 103,
#  'analyze': 104,
#  'detect': 105,
#  'predictive': 106,
#  'helping': 107,
#  'finance': 108,
#  'vast': 109,
#  'time': 110,
#  'use': 111,
#  'make': 112,
#  'decisions': 113,
#  'risks': 114,
#  'industry': 115,
#  'vehicles': 116,
#  'developing': 117,
#  'driving': 118,
#  'navigate': 119,
#  'entertainment': 120,
#  'art': 121,
#  'boundaries': 122,
#  'education': 123,
#  'adapting': 124,
#  'student': 125,
#  'impact': 126,
#  'engineering': 127,
#  'concerns': 128,
#  'ethical': 129,
#  'issues': 130,
#  'responsible': 131,
#  'regulation': 132,
#  'ensuring': 133,
#  'agi': 134,
#  'reshaping': 135,
#  'humans': 136,
#  'collaboration': 137,
#  'crucial': 138,
#  'society': 139,
#  'years': 140,
#  'come': 141,
#  'economic': 142,
#  'around': 143,
#  'interconnected': 144,
#  'digital': 145,
#  'humanity': 146,
#  'challenges': 147,
#  'study': 148,
#  'into': 149,
#  'past': 150,
#  'social': 151,
#  'structures': 152,
#  'leading': 153,
#  'governance': 154,
#  'saw': 155,
#  'empires': 156,
#  'thinkers': 157,
#  'roman': 158,
#  'generations': 159,
#  'exploration': 160,
#  'centuries': 161,
#  'technological': 162,
#  'wars': 163,
#  'movements': 164,
#  'rights': 165,
#  'transformative': 166,
#  'technologies': 167,
#  'mere': 168,
#  'concept': 169,
#  'fiction': 170,
#  'becoming': 171,
#  'integral': 172,
#  'part': 173,
#  'everyday': 174,
#  'refers': 175,
#  'simulation': 176,
#  'enabling': 177,
#  'perform': 178,
#  'typically': 179,
#  'require': 180,
#  'cognition': 181,
#  'problem': 182,
#  'solving': 183,
#  'decision': 184,
#  'journey': 185,
#  'traced': 186,
#  'back': 187,
#  'mid': 188,
#  'when': 189,
#  'pioneers': 190,
#  'alan': 191,
#  'john': 192,
#  'mccarthy': 193,
#  'theoretical': 194,
#  'foundations': 195,
#  'field': 196,
#  'turing’s': 197,
#  'work': 198,
#  'test': 199,
#  'mccarthy’s': 200,
#  'introduction': 201,
#  'term': 202,
#  '“artificial': 203,
#  'intelligence”': 204,
#  '1956': 205,
#  'were': 206,
#  'pivotal': 207,
#  'moments': 208,
#  'focused': 209,
#  'symbolic': 210,
#  'rule': 211,
#  'based': 212,
#  'which': 213,
#  'expert': 214,
#  '1970s': 215,
#  '1980s': 216,
#  'had': 217,
#  'limitations': 218,
#  'handling': 219,
#  'paradigm': 220,
#  'shift': 221,
#  'computers': 222,
#  'now': 223,
#  'learn': 224,
#  'rather': 225,
#  'than': 226,
#  'relying': 227,
#  'solely': 228,
#  'predefined': 229,
#  'rules': 230,
#  'subset': 231,
#  'leverages': 232,
#  'statistical': 233,
#  'techniques': 234,
#  'enable': 235,
#  'experience': 236,
#  'this': 237,
#  'paved': 238,
#  'advanced': 239,
#  'form': 240,
#  'inspired': 241,
#  'structure': 242,
#  'function': 243,
#  'brain’s': 244,
#  'neural': 245,
#  'networks': 246,
#  'many': 247,
#  'recent': 248,
#  'breakthroughs': 249,
#  'widely': 250,
#  'recognized': 251,
#  'voice': 252,
#  'assistants': 253,
#  'siri': 254,
#  'alexa': 255,
#  'google': 256,
#  'assistant': 257,
#  'utilize': 258,
#  'understand': 259,
#  'respond': 260,
#  'queries': 261,
#  'similarly': 262,
#  'chatbots': 263,
#  'revolutionizing': 264,
#  'service': 265,
#  'providing': 266,
#  'instant': 267,
#  'efficient': 268,
#  'responses': 269,
#  'inquiries': 270,
#  'playing': 271,
#  'critical': 272,
#  'role': 273,
#  'diagnosing': 274,
#  'diseases': 275,
#  'predicting': 276,
#  'patient': 277,
#  'outcomes': 278,
#  'treatment': 279,
#  'plans': 280,
#  'medical': 281,
#  'images': 282,
#  'x': 283,
#  'rays': 284,
#  'mris': 285,
#  'anomalies': 286,
#  'remarkable': 287,
#  'accuracy': 288,
#  'analytics': 289,
#  'doctors': 290,
#  'anticipate': 291,
#  'disease': 292,
#  'outbreaks': 293,
#  'optimize': 294,
#  'resource': 295,
#  'allocation': 296,
#  'hospitals': 297,
#  'used': 298,
#  'fraud': 299,
#  'detection': 300,
#  'algorithmic': 301,
#  'risk': 302,
#  'assessment': 303,
#  'financial': 304,
#  'institutions': 305,
#  'leverage': 306,
#  'amounts': 307,
#  'transaction': 308,
#  'identifying': 309,
#  'suspicious': 310,
#  'patterns': 311,
#  'indicate': 312,
#  'fraudulent': 313,
#  'activity': 314,
#  'models': 315,
#  'high': 316,
#  'frequency': 317,
#  'maximizing': 318,
#  'profits': 319,
#  'minimizing': 320,
#  'automotive': 321,
#  'experiencing': 322,
#  'companies': 323,
#  'tesla': 324,
#  'waymo': 325,
#  'uber': 326,
#  'self': 327,
#  'cars': 328,
#  'roads': 329,
#  'obstacles': 330,
#  'rely': 331,
#  'combination': 332,
#  'sensor': 333,
#  'fusion': 334,
#  'operate': 335,
#  'safely': 336,
#  'transforming': 337,
#  'enhancing': 338,
#  'recommendations': 339,
#  'streaming': 340,
#  'platforms': 341,
#  'netflix': 342,
#  'spotify': 343,
#  'analyzing': 344,
#  'preferences': 345,
#  'behavior': 346,
#  'personalize': 347,
#  'suggestions': 348,
#  'improving': 349,
#  'engagement': 350,
#  'additionally': 351,
#  'generated': 352,
#  'music': 353,
#  'pushing': 354,
#  'creativity': 355,
#  'demonstrating': 356,
#  'contribute': 357,
#  'artistic': 358,
#  'expression': 359,
#  'experiences': 360,
#  'instructional': 361,
#  'individual': 362,
#  'needs': 363,
#  'intelligent': 364,
#  'tutoring': 365,
#  'assess': 366,
#  'provide': 367,
#  'targeted': 368,
#  'feedback': 369,
#  'learners': 370,
#  'grasp': 371,
#  'complex': 372,
#  'concepts': 373,
#  'effectively': 374,
#  'grading': 375,
#  'automate': 376,
#  'evaluation': 377,
#  'assignments': 378,
#  'exams': 379,
#  'reducing': 380,
#  'burden': 381,
#  'educators': 382,
#  'ai’s': 383,
#  'market': 384,
#  'topic': 385,
#  'debate': 386,
#  'automating': 387,
#  'repetitive': 388,
#  'mundane': 389,
#  'creating': 390,
#  'opportunities': 391,
#  'fields': 392,
#  'robotics': 393,
#  'displacement': 394,
#  'persist': 395,
#  'prompting': 396,
#  'discussions': 397,
#  'need': 398,
#  'workforce': 399,
#  'reskilling': 400,
#  'upskilling': 401,
#  'initiatives': 402,
#  'considerations': 403,
#  'surrounding': 404,
#  'gaining': 405,
#  'prominence': 406,
#  'become': 407,
#  'widespread': 408,
#  'bias': 409,
#  'privacy': 410,
#  'weapons': 411,
#  'sparked': 412,
#  'debates': 413,
#  'transparent': 414,
#  'fair': 415,
#  'aligned': 416,
#  'values': 417,
#  'pressing': 418,
#  'challenge': 419,
#  'policymakers': 420,
#  'researchers': 421,
#  'holds': 422,
#  'immense': 423,
#  'possibilities': 424,
#  'ongoing': 425,
#  'focusing': 426,
#  'achieving': 427,
#  'general': 428,
#  '–': 429,
#  'capable': 430,
#  'performing': 431,
#  'any': 432,
#  'intellectual': 433,
#  'task': 434,
#  'do': 435,
#  'remains': 436,
#  'distant': 437,
#  'goal': 438,
#  'continue': 439,
#  'push': 440,
#  'what': 441,
#  'possible': 442,
#  'industries': 443,
#  'redefining': 444,
#  'interact': 445,
#  'technology': 446,
#  'continues': 447,
#  'evolve': 448,
#  'between': 449,
#  'governments': 450,
#  'businesses': 451,
#  'academia': 452,
#  'benefits': 453,
#  'maximized': 454,
#  'addressing': 455,
#  'determine': 456,
#  'continued': 457,
#  'thoughtful': 458,
#  'enhance': 459,
#  'capabilities': 460,
#  'drive': 461,
#  'growth': 462,
#  'quality': 463,
#  'people': 464,
#  'intricate': 465,
#  'tapestry': 466,
#  'woven': 467,
#  'countless': 468,
#  'stories': 469,
#  'conquest': 470,
#  'culture': 471,
#  'transformation': 472,
#  'earliest': 473,
#  'hunter': 474,
#  'gatherer': 475,
#  'continuously': 476,
#  'process': 477,
#  'provides': 478,
#  'insight': 479,
#  'forces': 480,
#  'achievements': 481,
#  'lessons': 482,
#  'inform': 483,
#  'first': 484,
#  'emerged': 485,
#  'africa': 486,
#  'millions': 487,
#  'ago': 488,
#  'gradually': 489,
#  'tools': 490,
#  'allowed': 491,
#  'thrive': 492,
#  'agriculture': 493,
#  '10': 494,
#  '000': 495,
#  'bce': 496,
#  'turning': 497,
#  'point': 498,
#  'formation': 499,
#  'permanent': 500,
#  'settlements': 501,
#  'sumerians': 502,
#  'mesopotamia': 503,
#  'egyptians': 504,
#  'along': 505,
#  'nile': 506,
#  'indus': 507,
#  'valley': 508,
#  'chinese': 509,
#  'dynasties': 510,
#  'all': 511,
#  'played': 512,
#  'roles': 513,
#  'shaping': 514,
#  'developed': 515,
#  'writing': 516,
#  'monumental': 517,
#  'architecture': 518,
#  'groundwork': 519,
#  'classical': 520,
#  'greeks': 521,
#  'romans': 522,
#  'who': 523,
#  'made': 524,
#  'contributions': 525,
#  'philosophy': 526,
#  'greek': 527,
#  'socrates': 528,
#  'plato': 529,
#  'aristotle': 530,
#  'foundation': 531,
#  'western': 532,
#  'philosophical': 533,
#  'thought': 534,
#  'law': 535,
#  'influenced': 536,
#  'decline': 537,
#  'empire': 538,
#  'fifth': 539,
#  'ushered': 540,
#  'middle': 541,
#  'ages': 542,
#  'period': 543,
#  'characterized': 544,
#  'feudalism': 545,
#  'religious': 546,
#  'influence': 547,
#  'cultural': 548,
#  'stagnation': 549,
#  'europe': 550,
#  'meanwhile': 551,
#  'islamic': 552,
#  'golden': 553,
#  'flourished': 554,
#  'scholars': 555,
#  'mathematics': 556,
#  'medicine': 557,
#  'astronomy': 558,
#  'renaissance': 559,
#  'beginning': 560,
#  '14th': 561,
#  'resurgence': 562,
#  'leonardo': 563,
#  'da': 564,
#  'vinci': 565,
#  'michelangelo': 566,
#  'galileo': 567,
#  'propelled': 568,
#  'knowledge': 569,
#  'forward': 570,
#  'european': 571,
#  'powers': 572,
#  'expanding': 573,
#  'reach': 574,
#  'colonization': 575,
#  'americas': 576,
#  'transatlantic': 577,
#  'slave': 578,
#  'trade': 579,
#  'exchange': 580,
#  'goods': 581,
#  'ideas': 582,
#  'across': 583,
#  'continents': 584,
#  'industrial': 585,
#  '18th': 586,
#  '19th': 587,
#  'further': 588,
#  'transformed': 589,
#  'introducing': 590,
#  'mechanized': 591,
#  'production': 592,
#  'urbanization': 593,
#  'shifts': 594,
#  'witnessed': 595,
#  'rapid': 596,
#  'redefined': 597,
#  'global': 598,
#  'politics': 599,
#  'two': 600,
#  'fall': 601,
#  'cold': 602,
#  'war': 603,
#  'establishment': 604,
#  'international': 605,
#  'organizations': 606,
#  'united': 607,
#  'nations': 608,
#  'civil': 609,
#  'movement': 610,
#  'feminist': 611,
#  'waves': 612,
#  'decolonization': 613,
#  'brought': 614,
#  'greater': 615,
#  'awareness': 616,
#  'equality': 617,
#  'justice': 618,
#  '21st': 619,
#  'created': 620,
#  'information': 621,
#  'accessible': 622,
#  'at': 623,
#  'click': 624,
#  'button': 625,
#  'progresses': 626,
#  'climate': 627,
#  'change': 628,
#  'ethics': 629,
#  'geopolitical': 630,
#  'tensions': 631,
#  'arise': 632,
#  'reminds': 633,
#  'us': 634,
#  'overcome': 635,
#  'adversity': 636,
#  'through': 637,
#  'understanding': 638,
#  'we': 639,
#  'present': 640,
#  'build': 641,
#  'equitable': 642,
#  'sustainable': 643,
#  'ever': 644,
#  'evolving': 645,
#  'story': 646,
#  'next': 647,
#  'chapters': 648,
#  'choices': 649,
#  'actions': 650,
#  'today’s': 651}
